# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
results = model.train(data='/home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/data.yaml', epochs=10, imgsz=640,)
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.12.1 torch-2.2.1+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# ...

# %%
pred = model('dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg',save= True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg: 640x640 1 white-knight, 2031.5ms
# Speed: 43.3ms preprocess, 2031.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train23

# %%
pred = model.predict('dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg',save= True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg: 640x640 1 white-knight, 976.0ms
# Speed: 62.9ms preprocess, 976.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train24

# %%
pred = model.predict('dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg',save= True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg: 640x640 1 white-knight, 192.5ms
# Speed: 73.9ms preprocess, 192.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train22

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.12.1 torch-2.2.1+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients
# val: Scanning /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/valid/labels.cache... 58 images, 0 backgrounds, 0 corrupt: 100%|██████████| 58/58 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:26<00:00,  6.62s/it]
#                    all         58        386      0.975      0.989      0.987      0.787
#           black-bishop         58         22      0.998      0.955      0.965        0.7
#             black-king         58         29      0.992          1      0.995      0.841
#           black-knight         58         30          1      0.981      0.995       0.79
#             black-pawn         58         77       0.99          1      0.995      0.791
# ...

# %%
results = model.train(data='/home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/data.yaml', epochs=10, imgsz=640,scale=0.7)
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.12.1 torch-2.2.1+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# ...

# %%
pred = model('dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg',save= True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/749e9074a77f8d34d86e2218f26cdab4_jpg.rf.b39c00c032a7ecbb62b8792bbe05497e.jpg: 640x640 1 white-knight, 2440.9ms
# Speed: 177.9ms preprocess, 2440.9ms inference, 28.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train24

# %%
pred = model('dataset/chess pieces/test/images/0b47311f426ff926578c9d738d683e76_jpg.rf.40183eae584a653181bbd795ba3c353f.jpg',save= True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/0b47311f426ff926578c9d738d683e76_jpg.rf.40183eae584a653181bbd795ba3c353f.jpg: 640x640 1 white-bishop, 1 white-queen, 910.4ms
# Speed: 49.3ms preprocess, 910.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/train242

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.12.1 torch-2.2.1+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# Model summary (fused): 168 layers, 3008183 parameters, 0 gradients
# val: Scanning /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/valid/labels.cache... 58 images, 0 backgrounds, 0 corrupt: 100%|██████████| 58/58 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:22<00:00,  5.69s/it]
#                    all         58        386      0.981      0.985      0.988      0.795
#           black-bishop         58         22          1      0.905      0.965      0.675
#             black-king         58         29          1      0.987      0.995      0.839
#           black-knight         58         30          1      0.996      0.995      0.813
#             black-pawn         58         77      0.994          1      0.995      0.798
# ...

# %%
results = model.train(model='runs/detect/model2/weights/best.pt',data='/home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/data.yaml', epochs=10, imgsz=640,scale=0.7)
# Out:
# Ultralytics YOLOv8.1.30 🚀 Python-3.12.1 torch-2.2.1+cu121 CPU (Intel Core(TM) i5-8400 2.80GHz)
# ...

# %%
model = YOLO('runs/detect/model3/weights/best.pt')

# %%
predition = model('/home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/b526b661a33ff481231d1342aff2a266_jpg.rf.287d21a885ec3abeb6da818a6a9cd05b.jpg',save=True)
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/b526b661a33ff481231d1342aff2a266_jpg.rf.287d21a885ec3abeb6da818a6a9cd05b.jpg: 640x640 1 black-bishop, 1 black-king, 2 black-knights, 5 black-pawns, 2 black-rooks, 2 white-bishops, 1 white-king, 1 white-knight, 4 white-pawns, 1 white-queen, 1 white-rook, 944.5ms
# Speed: 26.6ms preprocess, 944.5ms inference, 10.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
pr = model.predict('/home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/b526b661a33ff481231d1342aff2a266_jpg.rf.287d21a885ec3abeb6da818a6a9cd05b.jpg')
# Out:
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/dataset/chess pieces/test/images/b526b661a33ff481231d1342aff2a266_jpg.rf.287d21a885ec3abeb6da818a6a9cd05b.jpg: 640x640 1 black-bishop, 1 black-king, 2 black-knights, 5 black-pawns, 2 black-rooks, 2 white-bishops, 1 white-king, 1 white-knight, 4 white-pawns, 1 white-queen, 1 white-rook, 234.8ms
# Speed: 36.6ms preprocess, 234.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
pr[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'bishop', 1: 'black-bishop', 2: 'black-king', 3: 'black-knight', 4: 'black-pawn', 5: 'black-queen', 6: 'black-rook', 7: 'white-bishop', 8: 'white-king', 9: 'white-knight', 10: 'white-pawn', 11: 'white-queen', 12: 'white-rook'}
# obb: None
# orig_img: array([[[222, 224, 224],
#         [222, 224, 224],
#         [222, 224, 224],
#         ...,
#         [220, 222, 222],
#         [221, 223, 223],
#         [222, 224, 224]],
#
#        [[222, 224, 224],
#         [222, 224, 224],
#         [222, 224, 224],
#         ...,
#         [218, 220, 220],
#         [218, 220, 220],
#         [219, 221, 221]],
#
#        [[222, 224, 224],
#         [222, 224, 224],
#         [222, 224, 224],
#         ...,
#         [216, 218, 218],
#         [216, 218, 218],
#         [216, 218, 218]],
#
#        ...,
#
#        [[197, 205, 204],
# ...

# %%
pr[0].boxes[15].cls[0].item()
# Out:
# 10.0

# %%
pr[0].names
# Out:
# {0: 'bishop',
#  1: 'black-bishop',
#  2: 'black-king',
#  3: 'black-knight',
#  4: 'black-pawn',
#  5: 'black-queen',
#  6: 'black-rook',
#  7: 'white-bishop',
#  8: 'white-king',
#  9: 'white-knight',
#  10: 'white-pawn',
#  11: 'white-queen',
#  12: 'white-rook'}

# %%
p = model.predict('https://ultralytics.com/images/bus.jpg')
# Out:
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 3.33MB/s]
# image 1/1 /home/users/sourav.ml/Desktop/Projects/Object detection/bus.jpg: 640x480 3 black-knights, 2730.4ms
# Speed: 17.3ms preprocess, 2730.4ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 480)

# %%
with open('dataset/chess pieces/test/images/0b47311f426ff926578c9d738d683e76_jpg.rf.40183eae584a653181bbd795ba3c353f.jpg','rb') as f:
    image = f.read()

# %%
type(image)
# Out:
# bytes

# %%
import base64

image = base64.b64encode(image).decode('utf-8')
import requests

# %%
type(image)
# Out:
# str

# %%
from PIL import Image
from io import BytesIO
Pil_image = Image.open(BytesIO(base64.b64decode(image)))

# %%
image = BytesIO(base64.b64decode(image))

# %%
type(image)
# Out:
# _io.BytesIO

# %%
type(Pil_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
Pil_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416>

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/model3/weights/best.pt')

def detect_objects(url):
    det = model.predict(f'{url}')
    results = det[0]
    out = results.boxes[0].cls[0].item()
    # for box in results.boxes:
    return out
Image.fromarray(model.predict(Pil_image)[0].plot())
# Out:
# 0: 640x640 1 white-bishop, 95.4ms
# Speed: 5.6ms preprocess, 95.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/model1/weights/best.pt')

def detect_objects(url):
    det = model.predict(f'{url}')
    results = det[0]
    out = results.boxes[0].cls[0].item()
    # for box in results.boxes:
    return out
Image.fromarray(model.predict(Pil_image)[0].plot())
# Out:
# 0: 640x640 1 white-bishop, 1 white-queen, 218.0ms
# Speed: 18.1ms preprocess, 218.0ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>

# %%
from ultralytics import YOLO

model = YOLO('runs/detect/model2/weights/best.pt')

def detect_objects(url):
    det = model.predict(f'{url}')
    results = det[0]
    out = results.boxes[0].cls[0].item()
    # for box in results.boxes:
    return out
Image.fromarray(model.predict(Pil_image)[0].plot())
# Out:
# 0: 640x640 1 white-bishop, 109.5ms
# Speed: 3.8ms preprocess, 109.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# <PIL.Image.Image image mode=RGB size=416x416>
